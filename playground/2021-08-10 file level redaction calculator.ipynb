# %%
import numpy as np
import pandas as pd

# %%
# !pip install ../dist/redactioncalculator-0.1.0-py3-none-any.whl
# Out:
# Processing /Users/vegomez/Github/vvveracruz/nt-redaction-back-end/dist/redactioncalculator-0.1.0-py3-none-any.whl
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from redactioncalculator==0.1.0) (1.0.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.4.2 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from redactioncalculator==0.1.0) (3.4.2)
# Requirement already satisfied: ipython<8.0.0,>=7.24.1 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from redactioncalculator==0.1.0) (7.26.0)
# Requirement already satisfied: numpy<2.0.0,>=1.21.1 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from redactioncalculator==0.1.0) (1.21.1)
# Requirement already satisfied: pandas<2.0.0,>=1.2.5 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from redactioncalculator==0.1.0) (1.3.1)
# Requirement already satisfied: tabulate<0.9.0,>=0.8.9 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from redactioncalculator==0.1.0) (0.8.9)
# Requirement already satisfied: jedi>=0.16 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (0.18.0)
# Requirement already satisfied: matplotlib-inline in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (0.1.2)
# Requirement already satisfied: appnope in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (0.1.2)
# Requirement already satisfied: backcall in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (52.0.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (5.0.5)
# Requirement already satisfied: decorator in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (5.0.9)
# Requirement already satisfied: pygments in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (2.9.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (3.0.19)
# Requirement already satisfied: pickleshare in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jedi>=0.16->ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (0.8.2)
# Requirement already satisfied: qtconsole in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (5.1.1)
# Requirement already satisfied: ipywidgets in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (7.6.3)
# Requirement already satisfied: ipykernel in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (6.0.3)
# Requirement already satisfied: notebook in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (6.4.2)
# Requirement already satisfied: jupyter-console in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (6.4.0)
# Requirement already satisfied: nbconvert in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (6.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from matplotlib<4.0.0,>=3.4.2->redactioncalculator==0.1.0) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from matplotlib<4.0.0,>=3.4.2->redactioncalculator==0.1.0) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from matplotlib<4.0.0,>=3.4.2->redactioncalculator==0.1.0) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from matplotlib<4.0.0,>=3.4.2->redactioncalculator==0.1.0) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from matplotlib<4.0.0,>=3.4.2->redactioncalculator==0.1.0) (2.8.2)
# Requirement already satisfied: six in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from cycler>=0.10->matplotlib<4.0.0,>=3.4.2->redactioncalculator==0.1.0) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from pandas<2.0.0,>=1.2.5->redactioncalculator==0.1.0) (2021.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from pexpect>4.3->ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (0.2.5)
# Requirement already satisfied: ipython-genutils in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from traitlets>=4.2->ipython<8.0.0,>=7.24.1->redactioncalculator==0.1.0) (0.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (1.4.1)
# Requirement already satisfied: jupyter-client<7.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (6.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (6.1)
# Requirement already satisfied: importlib-metadata<4 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (3.10.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from importlib-metadata<4->ipykernel->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from importlib-metadata<4->ipykernel->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (3.5.0)
# Requirement already satisfied: pyzmq>=13 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jupyter-client<7.0->ipykernel->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jupyter-client<7.0->ipykernel->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (4.7.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jupyter-client<7.0->ipykernel->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (1.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (3.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (21.2.0)
# Requirement already satisfied: jinja2 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (3.0.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (1.8.0)
# Requirement already satisfied: prometheus-client in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (0.10.1)
# Requirement already satisfied: argon2-cffi in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (1.14.6)
# Requirement already satisfied: pycparser in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (2.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from jinja2->notebook->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (2.0.1)
# Requirement already satisfied: bleach in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (0.8.4)
# Requirement already satisfied: defusedxml in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (0.5.3)
# Requirement already satisfied: testpath in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (0.3)
# Requirement already satisfied: async-generator in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (1.10)
# Requirement already satisfied: webencodings in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (0.5.1)
# Requirement already satisfied: packaging in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (21.0)
# Requirement already satisfied: qtpy in /Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->redactioncalculator==0.1.0) (1.9.0)
# Installing collected packages: redactioncalculator
# Successfully installed redactioncalculator-0.1.0
# WARNING: You are using pip version 21.0.1; however, version 21.2.3 is available.
# You should consider upgrading via the '/Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/bin/python -m pip install --upgrade pip' command.

# %%
from redactioncalculator import OutputManager
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/17/kr6ksx895w97rzfkgkfdrr8c0000gn/T/ipykernel_61953/2088040354.py in <module>
# ----> 1 from redactioncalculator import OutputManager
#
# ImportError: cannot import name 'OutputManager' from 'redactioncalculator' (/Users/vegomez/Library/Caches/pypoetry/virtualenvs/redactioncalculator-Fcyid6aj-py3.7/lib/python3.7/site-packages/redactioncalculator/__init__.py)

# %%
class DistanceCalculator():
    '''
    Takes two files or a set of files and returns a dataframe containing the edit edit distance between each of them.
    '''
    def __init__(self, targets, sources=[]):
        self.targets=targets
        self.sources=sources
    
    # takes two files or a set of files
    # If sources is empty it returns the distance between all elements of the sources to each other

# %%
import numpy as np
import pandas as pd

def friendly_table_outputter(array, a, b):
    df = pd.DataFrame(array)
    df=df.set_index([list(a)])
    df=df.set_axis([list(b)], axis=1)
    
#     print(df, '\n')
    return df

def levenschtein_distance_basic(a, b, output_distance=True, output_table=False):
    a = ' '+a # a_0 is always the empty string
    b = ' '+b
    
    # costing
    deletion_cost = 1
    insertion_cost = 1
    
    D = np.zeros((len(a), len(b)), dtype=int)
    
    for i in range(len(a)):
        D[i][0] = i
    
    for j in range(len(b)):
        D[0][j] = j
        
    for j in range(1, len(b)):
        for i in range(1, len(a)):
            if a[i] == b[j]:
                substitution_cost = 0
            else:
                substitution_cost = 1
            
            D[i, j] = min(                          # can probably change what is counted as a change by creating a subfunction of this and tweaking it
                D[i-1, j] + deletion_cost,
                D[i, j-1] + insertion_cost, 
                D[i-1, j-1] + substitution_cost
            )
            
    if output_table:
        return friendly_table_outputter(D, a, b)
    if output_distance:
        return D[-1][-1]

def get_distances(func, sources, targets=[]):
    '''
    Returns a dataframe with the distances from the sources to the targets. 
    If targets is empty it returns the distance between all elements of the sources to each other
    
    Inputs
    
    func:       the distance calculator function to use
    sources:    list of strings
    targets:    empty list or list of strings
    
    Outputs:
    pd.DataFrame object with rows = sources and columns = targets.
    '''
    if targets == []:
        targets=sources
        
    df = pd.DataFrame( index = sources, columns = targets )
    
    for i in targets:
        for j in sources:
            df[i][j] = func(i, j)
    
    return df

# %%
levenschtein_distance_basic('kitten', 'sitting', output_distance=False, output_table=True)
# Out:
#       s  i  t  t  i  n  g
#    0  1  2  3  4  5  6  7
# k  1  1  2  3  4  5  6  7
# i  2  2  1  2  3  4  5  6
# t  3  3  2  1  2  3  4  5
# t  4  4  3  2  1  2  3  4
# e  5  5  4  3  2  2  3  4
# n  6  6  5  4  3  3  2  3

# %%
get_distances(levenschtein_distance_basic,['gonzalez','gomez'])
# Out:
#          gonzalez gomez
# gonzalez        0     4
# gomez           4     0
